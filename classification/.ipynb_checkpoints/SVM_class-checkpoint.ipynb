# %% [markdown]
# <h1>We will talk about the mathematical intuition for Support Vector Machines

# %% [markdown]
# <h3> Prerequisites

# %% [markdown]
# * **Vectors**
#
#   ![image.png](attachment:2589a291-b680-42f9-8020-29e8b86ddec6.png)
#
#   can call it a=(4,3)
#
#   ![image.png](attachment:4d58aa46-7606-470a-8827-25dc12b4dad2.png)
#
#   mangnitude of vector
#
#   ![image.png](attachment:2edac92a-442e-45c7-bf7a-b93b95d7d793.png)
#
#   direction of vector
#
# * **Dot-Product**
#
#   ![image.png](attachment:45965844-0739-4460-8c29-71930b47aafc.png)
#   ![image.png](attachment:a0bc9016-e3cd-4a27-9613-456234ad2b72.png)
#
# * **Hyperplane**
#
#     a subspace one dimension less than the ambient space

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix

# %%
data = fetch_openml(data_id=1464, as_frame=True)

# Extract features and target
X = data.data
y = data.target

# Check the target classes
print("Target classes:", y.unique())
# Out:
# Target classes: ['2', '1']
# Categories (2, object): ['1', '2']

# %%
# Convert to binary labels: 1 for donated, -1 for not donated
y = y.astype(int)
y[y == 1] = -1
y[y==2]= 1

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=500)

# %%
X_train.describe()
# Out:
#                V1          V2            V3          V4
# count  500.000000  500.000000    500.000000  500.000000
# mean     9.144000    5.386000   1346.500000   33.068000
# std      7.311236    5.850938   1462.734403   23.764614
# min      0.000000    1.000000    250.000000    2.000000
# 25%      2.000000    2.000000    500.000000   15.000000
# 50%      6.500000    4.000000   1000.000000   27.500000
# 75%     14.000000    7.000000   1750.000000   47.000000
# max     40.000000   50.000000  12500.000000   98.000000

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      748 non-null    int64
#  1   V2      748 non-null    int64
#  2   V3      748 non-null    int64
#  3   V4      748 non-null    int64
# dtypes: int64(4)
# memory usage: 23.5 KB

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
m,n = X_train.shape

# %%
w = np.zeros((n,))
b = 0

# %%
def hinge_loss(x,y,w,b):
    loss = max(0,1-y*(np.dot(w,x)+b))
    return loss

# %%
def compute_total_loss(X,y,w,b,loss_fn=hinge_loss):
    m,n = X.shape
    loss=0
    reg=0
    for i in range(m):
        loss+=loss_fn(X[i],y[i],w,b)
    reg+=np.sum(w**2)
    
    return (loss / m) + (reg / 2)

# %%
def compute_subgradient(X,y,w,b,C):
    m,n = X.shape
    dj_dw = np.zeros((n,))
    dj_db = 0
    for i in range(m):
        if y[i]*(np.dot(w,X[i])+b)>=1:
            dj_dw+=w
        else:
            dj_dw += w-C*y[i]*X[i]
            dj_db += -C*y[i]

    return (dj_dw/m),(dj_db/m)

# %%
def gradient_descent_with_eval(X_train, y_train, X_test, y_test,
                                w, b, C, alpha, n_iters, loss_fn, tol=1e-4):
    train_loss_history = []
    test_loss_history = []

    for i in range(n_iters):
        dj_dw, dj_db = compute_subgradient(X_train, y_train, w, b, C)

        w -= alpha * dj_dw
        b -= alpha * dj_db

        # Calculate loss on train and test
        train_loss = compute_total_loss(X_train, y_train, w, b, loss_fn)
        test_loss = compute_total_loss(X_test, y_test, w, b, loss_fn)

        train_loss_history.append(train_loss)
        test_loss_history.append(test_loss)

        if test_loss < tol:
            print(f"Stopped early at iteration {i} — test loss: {test_loss:.6f}")
            break

        if i % max(1, n_iters // 10) == 0:
            print(f"Iteration {i:4d}: Train Loss = {train_loss:.4f}, Test Loss = {test_loss:.4f}")

    return w, b, train_loss_history, test_loss_history

# %%
def predict(X,w,b):
    m,n = X.shape
    y = np.zeros((m,))
    for i in range(m):
        y[i] = np.sign(np.dot(w,X[i])+b)
    return y

# %%
def plot_loss(train_loss, test_loss):
    plt.figure(figsize=(8,5))
    plt.plot(train_loss, label="Train Loss")
    plt.plot(test_loss, label="Test Loss")
    plt.xlabel("Iteration")
    plt.ylabel("Loss")
    plt.title("Loss Curve (Train vs Test)")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
print(f"X.shape: {X.shape}, y.shape: {y.shape}")
# Out:
# X.shape: (748, 4), y.shape: (748,)

# %%
w,b,train_loss_history,test_losshistory = gradient_descent_with_eval(X_train,y_train.to_numpy(),X_test,y_test.to_numpy(),w,b,5,0.0001,10000,hinge_loss,1e-5)
# Out:
# Iteration    0: Train Loss = 0.9916, Test Loss = 0.9915
# Iteration 1000: Train Loss = 0.4768, Test Loss = 0.4766
# Iteration 2000: Train Loss = 0.4768, Test Loss = 0.4766
# Iteration 3000: Train Loss = 0.4768, Test Loss = 0.4766
# Iteration 4000: Train Loss = 0.4768, Test Loss = 0.4766
# Iteration 5000: Train Loss = 0.4768, Test Loss = 0.4766
# Iteration 6000: Train Loss = 0.4768, Test Loss = 0.4766
# Iteration 7000: Train Loss = 0.4768, Test Loss = 0.4766
# Iteration 8000: Train Loss = 0.4768, Test Loss = 0.4766
# Iteration 9000: Train Loss = 0.4768, Test Loss = 0.4766

# %%
plot_loss(train_loss_history,test_losshistory)

# %%
pred = predict(X_test,w,b)

# %%
cm = confusion_matrix(y_test.to_numpy(), pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['True 0', 'True 1'])
plt.ylabel('True labels')
plt.xlabel('Predicted labels')
plt.title('Confusion Matrix')
plt.show()
